# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mydata = pd.read_csv('/content/creditcard_2023.csv')

# %%
mydata.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
#Determing number of rows and column
num_rows = mydata.shape[0]
num_columns = mydata.shape[1]

#Print the number of rows and columns
print(f"Number of rows: {num_rows }")
print (f"Number of columns: {num_columns}")
# Out:
# Number of rows: 3683
# Number of columns: 31

# %%
mydata.dtypes
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
#Data Cleaning

#Checking for missing values
mydata.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#Handling missing values by imputation
mydata['V14'].fillna(mydata['V14'].mean(),inplace=True)
mydata['V15'].fillna(mydata['V15'].mean(),inplace=True)
mydata['V16'].fillna(mydata['V16'].mean(),inplace=True)
mydata['V17'].fillna(mydata['V17'].mean(),inplace=True)
mydata['V18'].fillna(mydata['V18'].mean(),inplace=True)
mydata['V19'].fillna(mydata['V19'].mean(),inplace=True)
mydata['V20'].fillna(mydata['V20'].mean(),inplace=True)
mydata['V21'].fillna(mydata['V21'].mean(),inplace=True)
mydata['V22'].fillna(mydata['V22'].mean(),inplace=True)
mydata['V23'].fillna(mydata['V23'].mean(),inplace=True)
mydata['V24'].fillna(mydata['V24'].mean(),inplace=True)
mydata['V25'].fillna(mydata['V19'].mean(),inplace=True)
mydata['V26'].fillna(mydata['V19'].mean(),inplace=True)
mydata['V27'].fillna(mydata['V19'].mean(),inplace=True)
mydata['V28'].fillna(mydata['V19'].mean(),inplace=True)
mydata['Amount'].fillna(mydata['V19'].mean(),inplace=True)
mydata['Class'].fillna(mydata['V19'].mean(),inplace=True)

# %%
mydata.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Visualization

#4.Histogram
plt.hist(mydata['V1'])
plt.xlabel('V1')
plt.ylabel('Frequency')
plt.title('Distribution of V1')
plt.show()

# %%
#5.Calculate the skewness
skewness_V2  = mydata['V2'].skew()
skewness_V3 = mydata['V3'].skew()

print(skewness_V2)
print(skewness_V3)
print()

#Visualize skewness
plt.figure(figsize = (10,6))
plt.subplot(2,1,1)
plt.hist(mydata['V2'], color = 'pink', alpha = 0.5)
plt.title( 'Distribution of V2')
plt.xlabel('Values of V2')
plt.ylabel('Frequency')

plt.subplot(2,1,2)
plt.hist(mydata['V3'], color = 'blue', alpha = 0.5)
plt.title( 'Distribution of V3')
plt.xlabel('Values of V3')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show
# Out:
# -8.231866628231238
# 0.5863200340070194
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#6.Bar plot for orders

#Group the data by category and calculate the number of orders
category_orders = mydata.groupby('V4')['id'].count()

#Create a bar plot
plt.bar(category_orders.index, category_orders.values)
plt.xlabel('V4')
plt.ylabel('Total Number of Orders')
plt.title('Total Number of Orders by category')
plt.show()

# %%
#7. Line Plot of amount over time
#plot the data
plt.plot(mydata['Class'],mydata['Amount'])
plt.title('Trend in Amount over Class')
plt.xlabel('Class')
plt.ylabel('Amount')
plt.show()

# %%
#8 Create a scatter plot
plt.scatter(mydata['id'],mydata['V5'])
plt.title('Scatter plot id vs V5')
plt.xlabel('id')
plt.ylabel('V5')
plt.show()

# %%
#Create a box plot
plt.boxplot(mydata['V6'])
plt.xlabel('class')
plt.ylabel('V6')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 10. Statistic summary
mydata.describe()
# Out:
#                 id           V1           V2           V3           V4  \
# count  3683.000000  3683.000000  3683.000000  3683.000000  3683.000000
# mean   3681.000272     0.230114    -0.373810     1.187249    -0.547266
# std    2812.337462     0.593431     0.514497     0.741183     0.639673
# min       0.000000    -2.296470   -14.821249    -1.420525    -3.996094
# 25%     920.500000    -0.196206    -0.513452     0.676144    -0.825902
# 50%    1841.000000     0.018737    -0.332732     1.103426    -0.435991
# 75%    6442.500000     0.902537    -0.131504     1.644915    -0.142454
# max    7363.000000     1.423966     1.576970     4.324138     1.471499
#
#                 V5           V6           V7           V8           V9  ...  \
# count  3683.000000  3683.000000  3683.000000  3683.000000  3683.000000  ...
# mean      0.295586     0.499301     0.482095    -0.166639     1.071450  ...
# std       0.502075     0.679063     0.715735     0.250492     1.008567  ...
# ...
